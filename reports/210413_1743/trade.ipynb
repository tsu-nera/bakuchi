# %% [markdown]
# # 取引履歴のデータ分析

# %%
import os
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
matplotlib.use("Agg")

# %%
current_dir = %pwd
timestamp = os.path.basename(current_dir)

# %%
import sys
sys.path.append('/home/tsu-nera/repo/bakuchi/')
# %cd '../../'
# Out:
# /home/ubuntu/repo/bakuchi

# %%
from src.utils.trade_analysis import TradeAnalysis

# %reload_ext autoreload
# %autoreload 2

# %%
ta = TradeAnalysis(timestamp)

# %%
ex1_trades = ta.get_ex1_trades_df()
ex2_trades = ta.get_ex2_trades_df()

# %%
len(ex1_trades), len(ex2_trades)
# Out:
# (183, 183)

# %% [markdown]
# ## トレード結果

# %%
ta.display()
# Out:
# トレード情報
# -------------------  -------------------
#          レコード数                12859
#            取引回数                  183
#            開始日時  2021-04-13 17:43:32
#            終了日時  2021-04-14 04:42:08
#         取引時間[H]             10:58:36
#       取引単位[BTC]               0.0005
#   利確しきい値[JPY]                 5000
# 損切りマージン[JPY]                 5000
# -------------------  -------------------
#
#
# トレード結果
# -----------  ------
# 開始[JPY]     13628
# 終了[JPY]     13043
# 利益[JPY]      -585
# 開始[BTC]    0.0024
# 終了[BTC]    0.0024
# 利益[BTC]         0
# 開始[TOTAL]   30068
# 終了[TOTAL]   29471
# 利益[TOTAL]    -597
# -----------  ------
#
#
# トレード利益
#   Bot利益    トレード利益    市場利益
# ---------  --------------  ----------
#      -597         -593.68       -3.32

# %% [markdown]
# ## 取引履歴

# %%
profit_df = ta.create_profit_df()

# %%
profit_df.tail(30)
# Out:
#                     ex1_side  ex1_price ex2_side  ex2_price  profit
# timestamp
# 2021-04-14 03:18:05     sell   3453.758      buy   3464.318 -10.560
# 2021-04-14 03:20:45      buy   3450.000     sell   3462.706  12.706
# 2021-04-14 03:21:28     sell   3450.124      buy   3459.966  -9.842
# 2021-04-14 03:22:45      buy   3448.808     sell   3459.499  10.691
# 2021-04-14 03:34:33     sell   3450.000      buy   3457.889  -7.889
# 2021-04-14 03:35:16      buy   3445.101     sell   3455.736  10.635
# 2021-04-14 03:45:40     sell   3440.000      buy   3448.415  -8.415
# 2021-04-14 03:45:50      buy   3436.356     sell   3447.618  11.262
# 2021-04-14 03:46:27     sell   3433.211      buy   3441.506  -8.295
# 2021-04-14 03:46:49      buy   3430.917     sell   3442.230  11.313
# 2021-04-14 03:53:43     sell   3427.990      buy   3438.926 -10.936
# 2021-04-14 03:54:20      buy   3420.303     sell   3433.692  13.389
# 2021-04-14 03:54:33     sell   3420.300      buy   3430.035  -9.735
# 2021-04-14 03:55:14      buy   3417.559     sell   3428.644  11.085
# 2021-04-14 03:56:59     sell   3412.000      buy   3423.330 -11.330
# 2021-04-14 03:57:18      buy   3410.863     sell   3426.309  15.446
# 2021-04-14 03:59:03     sell   3410.004      buy   3423.983 -13.979
# 2021-04-14 03:59:09      buy   3411.272     sell   3426.560  15.288
# 2021-04-14 04:02:11     sell   3415.836      buy   3428.599 -12.763
# 2021-04-14 04:02:52      buy   3416.591     sell   3431.028  14.437
# 2021-04-14 04:03:51     sell   3416.262      buy   3427.994 -11.732
# 2021-04-14 04:04:22      buy   3416.329     sell   3429.999  13.670
# 2021-04-14 04:12:18     sell   3420.577      buy   3430.001  -9.424
# 2021-04-14 04:14:33      buy   3419.148     sell   3430.313  11.165
# 2021-04-14 04:21:29     sell   3423.001      buy   3431.088  -8.087
# 2021-04-14 04:24:55      buy   3419.446     sell   3429.584  10.138
# 2021-04-14 04:27:20     sell   3420.305      buy   3427.500  -7.195
# 2021-04-14 04:27:27      buy   3420.305     sell   3428.471   8.166
# 2021-04-14 04:31:03     sell   3417.174      buy   3422.809  -5.635
# 2021-04-14 04:31:18      buy   3415.003     sell   3421.990   6.987

# %%
round(sum(profit_df.profit), 3)
# Out:
# 168.859

# %% [markdown]
# ## トレードグラフ

# %%
ex1_ticks = ta.get_ex1_ticks_df()
ex2_ticks = ta.get_ex2_ticks_df()

# %%
len(ex1_ticks), len(ex2_ticks)
# Out:
# (12859, 12859)

# %%
ex1_bids = ex1_ticks['bid']
ex1_asks = ex1_ticks['ask']
ex2_bids = ex2_ticks['bid']
ex2_asks = ex2_ticks['ask']

fig1, ax1 = ta.get_fig(ex1_bids, ex2_asks)
fig2, ax2 = ta.get_fig(ex2_bids, ex1_asks)

ax1.set_title('exchange1 bid/exchange2 ask')
ax2.set_title('exchange2 bid/exchange1 ask')
# Out:
# Text(0.5, 1.0, 'exchange2 bid/exchange1 ask')

# %%
fig1

# %%
fig2
